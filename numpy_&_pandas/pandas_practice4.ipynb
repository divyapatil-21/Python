# %%
import pandas as pd

df = pd.DataFrame({
    'Name': ['Riya', 'Priya', 'Divya', 'Neha', 'Aman', 'Rohan'],
    'City': ['Indore', 'Bhopal', 'Indore', 'Delhi', 'Bhopal', 'Indore'],
    'Subject': ['Maths', 'Science', 'English', 'Maths', 'Science', 'English'],
    'Marks': [85, 42, 77, 90, 35, 55],
    'Age': [20, 19, 21, 22, 18, 23]
})
print(df)
# Out:
#     Name    City  Subject  Marks  Age
# 0   Riya  Indore    Maths     85   20
# 1  Priya  Bhopal  Science     42   19
# 2  Divya  Indore  English     77   21
# 3   Neha   Delhi    Maths     90   22
# 4   Aman  Bhopal  Science     35   18
# 5  Rohan  Indore  English     55   23

# %%
#1️⃣ Display first 3 rows and last 2 rows

z=df.head(3)
y=df.tail(2)
print(z)
print(y)
# Out:
#     Name    City  Subject  Marks  Age
# 0   Riya  Indore    Maths     85   20
# 1  Priya  Bhopal  Science     42   19
# 2  Divya  Indore  English     77   21
#     Name    City  Subject  Marks  Age
# 4   Aman  Bhopal  Science     35   18
# 5  Rohan  Indore  English     55   23

# %%
#2️⃣ Display random 2 rows

z= df.sample(2)
print(z)
# Out:
#    Name    City  Subject  Marks  Age
# 0  Riya  Indore    Maths     85   20
# 4  Aman  Bhopal  Science     35   18

# %%
#3️⃣ Marks >= 60 filter karo
import pandas as pd

df = pd.DataFrame({
    'Name': ['Riya', 'Priya', 'Divya', 'Neha', 'Aman', 'Rohan'],
    'City': ['Indore', 'Bhopal', 'Indore', 'Delhi', 'Bhopal', 'Indore'],
    'Subject': ['Maths', 'Science', 'English', 'Maths', 'Science', 'English'],
    'Marks': [85, 42, 77, 90, 35, 55],
    'Age': [20, 19, 21, 22, 18, 23]
})
z= df[df['Marks']>=60]
print(z)
# Out:
#     Name    City  Subject  Marks  Age
# 0   Riya  Indore    Maths     85   20
# 2  Divya  Indore  English     77   21
# 3   Neha   Delhi    Maths     90   22

# %%
#4️⃣ Subject = "Maths" AND City = "Indore" filter karo
import pandas as pd

df = pd.DataFrame({
    'Name': ['Riya', 'Priya', 'Divya', 'Neha', 'Aman', 'Rohan'],
    'City': ['Indore', 'Bhopal', 'Indore', 'Delhi', 'Bhopal', 'Indore'],
    'Subject': ['Maths', 'Science', 'English', 'Maths', 'Science', 'English'],
    'Marks': [85, 42, 77, 90, 35, 55],
    'Age': [20, 19, 21, 22, 18, 23]
})
z= df[(df['Subject']== 'Maths') & (df['City'] == 'Indore')]
print(z)
# Out:
#    Name    City Subject  Marks  Age
# 0  Riya  Indore   Maths     85   20

# %%
#5️⃣ Marks ke descending order me sort karo

df = pd.DataFrame({
    'Name': ['Riya', 'Priya', 'Divya', 'Neha', 'Aman', 'Rohan'],
    'City': ['Indore', 'Bhopal', 'Indore', 'Delhi', 'Bhopal', 'Indore'],
    'Subject': ['Maths', 'Science', 'English', 'Maths', 'Science', 'English'],
    'Marks': [85, 42, 77, 90, 35, 55],
    'Age': [20, 19, 21, 22, 18, 23]
})
#print(df['Marks'].sort_values(ascending= False))
print(df.sort_values(by= 'Marks', ascending=False))
# Out:
#     Name    City  Subject  Marks  Age
# 3   Neha   Delhi    Maths     90   22
# 0   Riya  Indore    Maths     85   20
# 2  Divya  Indore  English     77   21
# 5  Rohan  Indore  English     55   23
# 1  Priya  Bhopal  Science     42   19
# 4   Aman  Bhopal  Science     35   18

# %%
#6️⃣ Naya column "Result"      add karo: Marks >= 40 → Pass Else → Fail
C
#df['Result']= df['Marks'].apply(lambda x : "pass" if x>=40 else "fail")
df['Result']= np.where(df['Marks']>= 40 , 'Pass', 'Fail')
print(df)
# Out:
#     Name    City  Subject  Marks  Age Result
# 0   Riya  Indore    Maths     85   20   Pass
# 1  Priya  Bhopal  Science     42   19   Pass
# 2  Divya  Indore  English     77   21   Pass
# 3   Neha   Delhi    Maths     90   22   Pass
# 4   Aman  Bhopal  Science     35   18   Fail
# 5  Rohan  Indore  English     55   23   Pass

# %%
#7️⃣ Naya column "Percentage" add karo = Marks / 100 * 100
df['Percentage']= ((df['Marks']/100)*100)
print(df)
# Out:
#     Name    City  Subject  Marks  Age Result  Percentage
# 0   Riya  Indore    Maths     85   20   Pass        85.0
# 1  Priya  Bhopal  Science     42   19   Pass        42.0
# 2  Divya  Indore  English     77   21   Pass        77.0
# 3   Neha   Delhi    Maths     90   22   Pass        90.0
# 4   Aman  Bhopal  Science     35   18   Fail        35.0
# 5  Rohan  Indore  English     55   23   Pass        55.0

# %%
#8️⃣ Name ko uppercase me convert karo
df['Name']= df['Name'].str.upper()
print(df)
# Out:
#     Name    City  Subject  Marks  Age Result  Percentage
# 0   RIYA  Indore    Maths     85   20   Pass        85.0
# 1  PRIYA  Bhopal  Science     42   19   Pass        42.0
# 2  DIVYA  Indore  English     77   21   Pass        77.0
# 3   NEHA   Delhi    Maths     90   22   Pass        90.0
# 4   AMAN  Bhopal  Science     35   18   Fail        35.0
# 5  ROHAN  Indore  English     55   23   Pass        55.0

# %%
#9️⃣ City column me sirf rows dikhao jisme "o" letter ho
df = pd.DataFrame({
    'Name': ['Riya', 'Priya', 'Divya', 'Neha', 'Aman', 'Rohan'],
    'City': ['Indore', 'Bhopal', 'Indore', 'Delhi', 'Bhopal', 'Indore'],
    'Subject': ['Maths', 'Science', 'English', 'Maths', 'Science', 'English'],
    'Marks': [85, 42, 77, 90, 35, 55],
    'Age': [20, 19, 21, 22, 18, 23]
})
print(df[ df['City'].str.contains('o', case= False)])
# Out:
#     Name    City  Subject  Marks  Age
# 0   Riya  Indore    Maths     85   20
# 1  Priya  Bhopal  Science     42   19
# 2  Divya  Indore  English     77   21
# 4   Aman  Bhopal  Science     35   18
# 5  Rohan  Indore  English     55   23

# %%
#🔟 Age me 2 NaN values manually add karo, phir:     isna()   fillna(Average age)    dropna()

data = {
    'Name': ['Riya', 'Priya', 'Divya', None],
    'Age': [20, None, 19, 22],
    'City': ['Indore', 'Bhopal', None, 'Delhi']
}
df = pd.DataFrame(data)
df['Age']= df['Age'].fillna(df['Age'].mean())
print(df)
#print(df.isna())
#print(df.dropna())
# Out:
#     Name        Age    City
# 0   Riya  20.000000  Indore
# 1  Priya  20.333333  Bhopal
# 2  Divya  19.000000    None
# 3   None  22.000000   Delhi
