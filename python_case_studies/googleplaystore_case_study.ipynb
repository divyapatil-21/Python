# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('D:/Pandas_Practice_case_studies/googleplaystore.csv')
df.sample(5)
# Out:
#                                                     App            Category  \
# 1204  Delivery trough - delivery trough delivery trough      FOOD_AND_DRINK
# 6253                        Treadmill Workouts Free (P)  HEALTH_AND_FITNESS
# 1119  Hurdlr: Track Mileage, Expenses, and Log Receipts             FINANCE
# 4998                                      AE Basketball              SPORTS
# 6828                                    BU Beauty Rooms              BEAUTY
#
#       Rating Reviews                Size    Installs  Type Price  \
# 1204     4.3   58316  Varies with device  5,000,000+  Free     0
# 6253     3.3      10                3.3M      1,000+  Free     0
# 1119     4.6    3596                 19M    100,000+  Free     0
# 4998     4.0    8100  Varies with device  1,000,000+  Free     0
# 6828     NaN       1                6.0M         50+  Free     0
#
#      Content Rating            Genres       Last Updated         Current Ver  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# #### 1. Which of the following columns has/have null values?

# %%
df.isna().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %% [markdown]
# #### clean the rating column and other columns containing null values

# %%
df['Rating'].unique()
# Out:
# array([ 4.1,  3.9,  4.7,  4.5,  4.3,  4.4,  3.8,  4.2,  4.6,  3.2,  4. ,
#         nan,  4.8,  4.9,  3.6,  3.7,  3.3,  3.4,  3.5,  3.1,  5. ,  2.6,
#         3. ,  1.9,  2.5,  2.8,  2.7,  1. ,  2.9,  2.3,  2.2,  1.7,  2. ,
#         1.8,  2.4,  1.6,  2.1,  1.4,  1.5,  1.2, 19. ])

# %%
df['Rating'] = df['Rating'].replace(19, np.nan)

# %%
df['Rating'].unique()
# Out:
# array([4.1, 3.9, 4.7, 4.5, 4.3, 4.4, 3.8, 4.2, 4.6, 3.2, 4. , nan, 4.8,
#        4.9, 3.6, 3.7, 3.3, 3.4, 3.5, 3.1, 5. , 2.6, 3. , 1.9, 2.5, 2.8,
#        2.7, 1. , 2.9, 2.3, 2.2, 1.7, 2. , 1.8, 2.4, 1.6, 2.1, 1.4, 1.5,
#        1.2])

# %%
df['Rating'].mean()
# Out:
# np.float64(4.191757420456972)

# %%
df['Rating'] = df['Rating'].fillna(4.1)

# %%
df.isna().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              1
# Price             0
# Content Rating    1
# Genres            0
# Last Updated      0
# Current Ver       8
# Android Ver       3
# dtype: int64

# %%
df['Rating'] = df['Rating'].fillna(df['Rating'].mean())

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %% [markdown]
# #### Clean the column Reviews and make it numeric

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          10841 non-null  float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
df['Reviews'].head()
# Out:
# 0       159.0
# 1       967.0
# 2     87510.0
# 3    215644.0
# 4       967.0
# Name: Reviews, dtype: float64

# %%
df['Reviews Numeric']=pd.to_numeric(df['Reviews'], errors='coerce')
df['Reviews Numeric']
# Out:
# 0           159.0
# 1           967.0
# 2         87510.0
# 3        215644.0
# 4           967.0
#            ...
# 10836        38.0
# 10837         4.0
# 10838         3.0
# 10839       114.0
# 10840    398307.0
# Name: Reviews Numeric, Length: 10841, dtype: float64

# %%
df.loc[df['Reviews Numeric'].isna()]
# Out:
#                                            App Category  Rating  Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9     4.1      NaN
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver  Reviews Numeric
# 10472       1.0.19  4.0 and up         NaN              NaN

# %% [markdown]
# #### How many duplicates apps are there?

# %%
df['App'].duplicated().sum()
# Out:
# np.int64(1181)

# %%
df.loc[df.duplicated(subset=['App'])].sort_values(by= 'App').head()
# Out:
#                                                     App            Category  \
# 1407                              10 Best Foods for You  HEALTH_AND_FITNESS
# 2543                         1800 Contacts - Lens Store             MEDICAL
# 2385                         2017 EMRA Antibiotic Guide             MEDICAL
# 1434                       21-Day Meditation Experience  HEALTH_AND_FITNESS
# 5415                            365Scores - Live Scores              SPORTS
# ...                                                 ...                 ...
# 3055  theScore: Live Sports Scores, News, Stats & Vi...              SPORTS
# 3014  theScore: Live Sports Scores, News, Stats & Vi...              SPORTS
# 3202                           trivago: Hotels & Travel    TRAVEL_AND_LOCAL
# 3118                           trivago: Hotels & Travel    TRAVEL_AND_LOCAL
# 8291                     wetter.com - Weather and Radar             WEATHER
#
# ...

# %% [markdown]
# #### Drop duplicated apps keeping the ones with the greatest number of reviews
