# %%
name="Divya Patil"
age= 23
fav_number= 1
print(f"my name is {name}, I am {age} year old and my favorite number is {fav_number}")
# Out:
# my name is Divya Patil, I am 23 year old and my favorite number is 1

# %%
a=10
b=20
a,b=b,a
print(a,b)
# Out:
# 20 10

# %%
x=10
x="divi"
print(x)
# Out:
# divi

# %%
def myfunc():
    x="im inside a function"
    print(x)
myfunc()

#local variable sirf function ke andar accessible hote h hm inhe function ke bahar access nhi kr skte h  
#or global variable agr function ke bahar define kia ho to bhi wo function ke andar accessible hote h
# Out:
# im inside a function

# %%
x="How are you?"
def myfunc():
    print(x)
myfunc()   # this is the example of gloBal variable
# Out:
# How are you?
