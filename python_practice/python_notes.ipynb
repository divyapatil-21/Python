# %%
variable length argument(* args & **kwargs)
lamda functions (anonymous one line functions)
map()
filter()
reduce()

list comprehensions
dictionary comprehensions
set comprehension
positional arguments


what is an exceptional
why exceptional handling important
multiple exception handling


syntaax:   
try:

    except exception type:
               
using else and finally
raising custom exceptions
i/o in python
opening files in pythoon and common modes
iterating through a file
Appending to a file
working with binary files
working with json files (dump and load)
working with csv files(writer and reader file)
exception handling in files
what is loggings?
loggings lables: info, warning, error
enviornment variable


regular expression('pattern matching k lie use hota h' )
the regular expression module
using re.search() loke find()
wild card characters
fine tunning your matches
matching and extracting data
warning greedy matches
non greedy matches
regx version

oops concept
class
object
construction
instances
static variables
encapsulation
inheritance
polymorphism
operator overloading and overriding
special methods(dunder methods)
composition


function is in an object
methods public, private , protected


pandas series and datafram
 series;- values, index, name, dtype

pandas data types;- numric, objext/text, time series

type conversion;- astype(datatype)

index
custom indices

the iloc method: index location(default index)

loc method(custom index)

duplicate
reset the index
filtering series

logical operartor and methods
sorting series

arithmatic operators and methods

string methods

numric series aggregstion

quaaaantile percentile in python

categorical series aggregation

missing data handling

nan(f;oat)
<na> int type


dropna()
fillna()

the apply method

where  method

chainning where 


numpy vs pandas where




dataframe 
creating dataframe
explore dataframe: head, tail, sample, info, describe

accessing dataframe columns: nunique, mean, iloc, summ

accessing data with iloc and loc

dropping rows and columns

identify duplicate rows and columns : keep, ignore_index, subset

identify missing data

handling missing data: fillna(), fillna({})

filtering dataframes

.query() and @ method 

sorting dataframes by indices: soort_index
sorting dataframes by values: .sort_value() method

renaming columns.column, .upper(), .rename()

reordering columns:.reindex()

arithmatic columns creation

boolean column creation

numpy select()

mapping values to columns: .map(), using lamda function
column creation with assign

pandas data types

categorical data type
type conversion

memory optimization tip
drop columns
memory_usage(deep=true)
converting object data type
downcast numeric data

when we create pipelines than use memory optimization


aggreGating dataframes
grouping dataframes: .groupby(), multiple columns
multiindex dataframes
modifying multi-index dataframes

the AGG method: .agg()
multiple aggregation 
named aggregation
transform: .transform()

pivot tables : .pivot_table()

pivot table arguments: index, columns, values, aggfunc, margins

multiple aggregation functions

pivot table vs group by 

Heatmaps: .style.background_gredient()
melt: .melt()

data visualization:
plot methood: .plot(), change the axis

chat formating
chart legend
gridlines
subplots
more data visualization  : matplotlib, seaborn, plotly, folium


importing annd exprting data:  read_csv(), columns name, setting index, selecting columns,
                               missing values, parsing dates, datatypes,converters,reading text files, read_excel(),
                               appending sheets, exporting to flat files,

connecting to sql database: mysql, oracle, ms-sql etc
querying sql databases
writing to sql database: to_sql()

Additional formates: json, feather, html pickel

combining dataframes: appending, 
joining: types of joins, join(), merge(), concate()
combining

date handling
string handling
