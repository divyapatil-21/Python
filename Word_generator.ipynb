# %%
import random
words = ["Riya", "Priya", "Divya"]
random_char = random.choice(words)
print(random_char)

word_len= len(random_char)
print(word_len)

if random_char == word_len:
    print("_",word_len)
# Out:
# Priya
# 5
