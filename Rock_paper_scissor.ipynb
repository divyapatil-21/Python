# %% [markdown]
# ## Rock Paper Scissor

# %%
import random
choices = ["rock", "paper", "scissor"]


count =0
while count<3:
    count+=1
    user_choice = input("user Choice:").lower()
    computer_choice = random.choice(choices)
    print("Computer choice:", computer_choice)
    if user_choice == computer_choice:
            print("It's Tie")
        
    elif user_choice == "rock":
            if computer_choice == "Scissor":
                print("Congratulation you win!! Rock beats scissor")
            else:
                print("you lose!!")
                
    elif user_choice == "scissor":
            if computer_choice == "paper":
                print("Congratulation you win!! Scissor cut paper")
            else:
                print(" you lose!!")
    elif user_choice == "paper":
            if computer_choice == "rock":
                print("Congratulation you win!! paper beats rock")
            else:
                print("you lose!!")  
    else:   
            print("Invalalid input please choose rock, paper, scissor")
print("Game Over!")
# Out:
# user Choice: rock
# Computer choice: rock
# It's Tie
# user Choice: paper
# Computer choice: scissor
# you lose!!
# user Choice: sc
# Computer choice: paper
# Invalalid input please choose rock, paper, scissor
# Game Over!
